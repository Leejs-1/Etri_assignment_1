# %% [markdown]
# # 데이터 이해 및 전처리

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

DATA_PATH = './DATA/' #데이터경로 설정

# %%
train_data = pd.read_table(DATA_PATH + 'ratings_train.txt')
test_data = pd.read_table(DATA_PATH + 'ratings_test.txt')

# %%
train_data.head()
# Out:
#          id                                           document  label
# 0   9976970                                아 더빙.. 진짜 짜증나네요 목소리      0
# 1   3819312                  흠...포스터보고 초딩영화줄....오버연기조차 가볍지 않구나      1
# 2  10265843                                  너무재밓었다그래서보는것을추천한다      0
# 3   9045019                      교도소 이야기구먼 ..솔직히 재미는 없다..평점 조정      0
# 4   6483659  사이몬페그의 익살스런 연기가 돋보였던 영화!스파이더맨에서 늙어보이기만 했던 커스틴 ...      1

# %%
#긍정 1, 부정 0
print('긍정 리뷰 갯수: {}'.format(train_data['label'].value_counts()[1]))
print('부정 리뷰 갯수: {}'.format(train_data['label'].value_counts()[0]))
# Out:
# 긍정 리뷰 갯수: 74827
# 부정 리뷰 갯수: 75173

# %% [markdown]
# ## 데이터 전처리

# %%
import numpy as np
import pandas as pd
import re
import json
from konlpy.tag import Okt
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.preprocessing.text import Tokenizer

# %%
train_data['document'][:5]
# Out:
# 0                                  아 더빙.. 진짜 짜증나네요 목소리
# 1                    흠...포스터보고 초딩영화줄....오버연기조차 가볍지 않구나
# 2                                    너무재밓었다그래서보는것을추천한다
# 3                        교도소 이야기구먼 ..솔직히 재미는 없다..평점 조정
# 4    사이몬페그의 익살스런 연기가 돋보였던 영화!스파이더맨에서 늙어보이기만 했던 커스틴 ...
# Name: document, dtype: object

# %%
# 한글과 공백을 제외하고 모두 제거
train_data['document'] = train_data['document'].str.replace('[^ㄱ-ㅎㅏ-ㅣ가-힣 ]','')
train_data['document'][:5]
# Out:
# 0                                    아 더빙 진짜 짜증나네요 목소리
# 1                           흠포스터보고 초딩영화줄오버연기조차 가볍지 않구나
# 2                                    너무재밓었다그래서보는것을추천한다
# 3                            교도소 이야기구먼 솔직히 재미는 없다평점 조정
# 4    사이몬페그의 익살스런 연기가 돋보였던 영화스파이더맨에서 늙어보이기만 했던 커스틴 던...
# Name: document, dtype: object

# %%
train_data['document'] = train_data['document'].str.replace('^ +', "") # white space 데이터를 empty value로 변경
train_data['document'].replace('', np.nan, inplace=True) # 리뷰에 비어있으면 NULL 값으로 대체
# NULL값이 존재하는 행이 있는지 확인
print(train_data.isnull().sum())
# Out:
# id             0
# document    1260
# label          0
# dtype: int64

# %%
# NULL값이 존재하는 5개의 행 출력
train_data.loc[train_data.document.isnull()][:5]
# Out:
#            id document  label
# 404   4221289      NaN      0
# 412   9509970      NaN      1
# 470  10147571      NaN      1
# 584   7117896      NaN      0
# 593   6478189      NaN      0

# %%
train_data = train_data.dropna(how = 'any')
print('전처리 후 train 데이터의 개수: ', len(train_data))
# Out:
# 전처리 후 train 데이터의 개수:  148740

# %%
# train 데이터와 마찬가지로 test 데이터 전처리
test_data['document'] = test_data['document'].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]","") # 정규 표현식 수행
test_data['document'] = test_data['document'].str.replace('^ +', "") # 공백은 empty 값으로 변경
test_data['document'].replace('', np.nan, inplace=True) # empty은 NULL 값으로 변경
test_data = test_data.dropna(how='any') # NULL 값 제거
print('전처리 후 test 데이터의 개수 :',len(test_data))
# Out:
# 전처리 후 test 데이터의 개수 : 49575

# %%
# 불용어 정의
stopwords = ['은','는','이','가','하','아','것','들','의','있','되',
             '수','보','주','등','한', '좀', '잘', '걍', '과', '도',
             '을', '를', '으로', '자', '에', '와', '하다']
okt = Okt()

# %%
# 형태소 분석기 okt를 통해 토근화를 하면서 불용어 제거 후 X_train에 저장
X_train = []
for sentence in train_data['document']:
    tokenized_sentence = okt.morphs(sentence, stem=True) # 토큰화
    stopwords_removed_sentence = [word for word in tokenized_sentence if not word in stopwords] # 불용어 제거
    X_train.append(stopwords_removed_sentence)

# %%
print(X_train[:4])
# Out:
# [['더빙', '진짜', '짜증나다', '목소리'], ['흠', '포스터', '보고', '초딩', '영화', '줄', '오버', '연기', '조차', '가볍다', '않다'], ['너', '무재', '밓었', '다그', '래서', '보다', '추천', '다'], ['교도소', '이야기', '구먼', '솔직하다', '재미', '없다', '평점', '조정']]

# %%
# train 데이터와 마찬가지로 test 데이터 토큰화 및 불용어 제거
X_test = []
for sentence in test_data['document']:
    tokenized_sentence = okt.morphs(sentence, stem=True) # 토큰화
    stopwords_removed_sentence = [word for word in tokenized_sentence if not word in stopwords] # 불용어 제거
    X_test.append(stopwords_removed_sentence)

# %%
# 기계가 텍스트를 숫자로 처리할 수 있도록 train데이터에 정수 인코딩 수행, 먼저 train데이터에 대해 단어 집합 생성
tokenizer = Tokenizer()
tokenizer.fit_on_texts(X_train)

# %%
print(tokenizer.word_index)
# Out:
# {'영화': 1, '보다': 2, '없다': 3, '이다': 4, '있다': 5, '좋다': 6, '너무': 7, '다': 8, '정말': 9, '재밌다': 10, '되다': 11, '적': 12, '만': 13, '같다': 14, '진짜': 15, '로': 16, '아니다': 17, '않다': 18, '점': 19, '에서': 20, '만들다': 21, '나오다': 22, '연기': 23, '평점': 24, '최고': 25, '내': 26, '그': 27, '나': 28, '안': 29, '인': 30, '스토리': 31, '생각': 32, '못': 33, '왜': 34, '드라마': 35, '게': 36, '감동': 37, '사람': 38, '보고': 39, '이렇다': 40, '말': 41, '아깝다': 42, '고': 43, '더': 44, 'ㅋㅋ': 45, '배우': 46, '때': 47, '재미있다': 48, '감독': 49, '거': 50, '그냥': 51, '요': 52, '재미': 53, '시간': 54, '내용': 55, '뭐': 56, '까지': 57, '중': 58, '주다': 59, '재미없다': 60, '자다': 61, '쓰레기': 62, '하고': 63, '지루하다': 64, '네': 65, '모르다': 66, '가다': 67, '들다': 68, '그렇다': 69, '싶다': 70, '지': 71, '작품': 72, '사랑': 73, '알다': 74, '하나': 75, '다시': 76, '볼': 77, '마지막': 78, '이건': 79, '정도': 80, '저': 81, '완전': 82, 'ㅋ': 83, '오다': 84, 'ㅠㅠ': 85, '많다': 86, 'ㅋㅋㅋ': 87, '처음': 88, '장면': 89, '액션': 90, '주인공': 91, '이렇게': 92, '걸': 93, '안되다': 94, '차다': 95, '최악': 96, '나다': 97, '개': 98, '돈': 99, '이야기': 100, '지금': 101, '별로': 102, '넘다': 103, '느낌': 104, '임': 105, 'ㅡㅡ': 106, '연출': 107, '라': 108, '인데': 109, '명작': 110, '듯': 111, '끝': 112, '좋아하다': 113, '그리고': 114, '역시': 115, '기': 116, '년': 117, '받다': 118, '별': 119, '많이': 120, '남다': 121, '이해': 122, '난': 123, '면': 124, '이런': 125, '괜찮다': 126, '이영화': 127, '분': 128, '라고': 129, '느끼다': 130, '또': 131, '버리다': 132, '이나': 133, '때문': 134, '성': 135, '여자': 136, '서': 137, '부터': 138, '먹다': 139, '일': 140, '아름답다': 141, '해주다': 142, '꼭': 143, '보기': 144, '엔': 145, '에게': 146, '두': 147, '이고': 148, '무슨': 149, '여': 150, '짱': 151, '기억': 152, '결말': 153, 'ㅎㅎ': 154, '편': 155, '대': 156, '마음': 157, '랑': 158, '야': 159, '전': 160, '인생': 161, '아쉽다': 162, '영': 163, '소재': 164, '뻔하다': 165, '끄다': 166, '어떻다': 167, '애': 168, '보여주다': 169, '님': 170, '없이': 171, '수준': 172, '어리다': 173, '현실': 174, '무섭다': 175, '재다': 176, '맞다': 177, '속': 178, '한번': 179, '씨': 180, '가장': 181, '본': 182, '급': 183, '웃기다': 184, '매력': 185, '반전': 186, '되어다': 187, '전개': 188, '제': 189, '라는': 190, '한국': 191, '남자': 192, '끝나다': 193, '가슴': 194, '뿐': 195, '말다': 196, '낮다': 197, '아이': 198, '슬프다': 199, '죽다': 200, '높다': 201, '유치하다': 202, '알': 203, '멋지다': 204, '음악': 205, '니': 206, '다른': 207, '원작': 208, '줄': 209, '늘다': 210, '화': 211, '인간': 212, '냐': 213, '솔직하다': 214, '크다': 215, '추천': 216, '우리': 217, '쓰다': 218, '눈물': 219, '인지': 220, '살다': 221, '함': 222, '모든': 223, '지만': 224, '내다': 225, '자체': 226, '번': 227, '야하다': 228, '허다': 229, '눈': 230, '찍다': 231, '하지만': 232, '인가': 233, '보이다': 234, '캐릭터': 235, '대박': 236, '코미디': 237, '처럼': 238, 'ㅋㅋㅋㅋ': 239, '움': 240, '대한': 241, '모두': 242, '뭔가': 243, '이상': 244, '돼다': 245, 'ㅠ': 246, '이네': 247, '전혀': 248, '이쁘다': 249, '연기력': 250, '건지다': 251, '여운': 252, '미치다': 253, '그래도': 254, '짜증나다': 255, '개봉': 256, '공감': 257, '기대하다': 258, '기대': 259, '일본': 260, '시리즈': 261, '지다': 262, '근데': 263, '중간': 264, '표현': 265, '굿': 266, '아주': 267, '영상': 268, '부분': 269, '모습': 270, '에는': 271, '작': 272, '계속': 273, '제목': 274, '이랑': 275, '귀엽다': 276, 'ㅜㅜ': 277, '치다': 278, '시키다': 279, '이라': 280, '가족': 281, '내내': 282, '보지': 283, '뭔': 284, '믿다': 285, '진심': 286, '실망': 287, '몰입': 288, '밖에': 289, '후': 290, 'ㅎ': 291, '짜다': 292, '대단하다': 293, '기분': 294, '연': 295, '떨어지다': 296, '작가': 297, '건': 298, '잔잔하다': 299, '이제': 300, '위': 301, '웃다': 302, '요즘': 303, '잼': 304, '빠지다': 305, '공포': 306, '스릴러': 307, '이라는': 308, '시': 309, '용': 310, '감': 311, '긴장감': 312, '개인': 313, '점도': 314, '조금': 315, '알바': 316, '애니': 317, '대사': 318, '이유': 319, '특히': 320, '제대로': 321, '삶': 322, '울다': 323, '극장': 324, '노래': 325, '노잼': 326, '한테': 327, '딱': 328, '점수': 329, '욕': 330, '잇다': 331, '시작': 332, '막장': 333, '이란': 334, '나름': 335, '이상하다': 336, '오랜': 337, '극': 338, '이지': 339, '예쁘다': 340, '깊다': 341, '에도': 342, '제일': 343, '차라리': 344, '놈': 345, '느껴지다': 346, '친구': 347, '영화로': 348, '해보다': 349, '당시': 350, '같이': 351, '어설프다': 352, '의미': 353, '절대': 354, '빼다': 355, '식': 356, '따뜻하다': 357, '위해': 358, '력': 359, '류': 360, '세상': 361, '찾다': 362, '몇': 363, '아직도': 364, '훌륭하다': 365, '년대': 366, '이라고': 367, '명': 368, '공포영화': 369, '미국': 370, '웃음': 371, '도대체': 372, '생각나다': 373 ...

# %%
type(tokenizer.word_index)
# Out:
# dict

# %%
threshold = 3
total_cnt = len(tokenizer.word_index) # 단어의 수
rare_cnt = 0 # 등장 빈도수가 threshold보다 작은 단어의 개수를 카운트
total_freq = 0 # 훈련 데이터의 전체 단어 빈도수 총 합
rare_freq = 0 # 등장 빈도수가 threshold보다 작은 단어의 등장 빈도수의 총 합

# 단어와 빈도수의 쌍(pair)을 key와 value로 받는다.
for key, value in tokenizer.word_counts.items():
    total_freq = total_freq + value

    # 단어의 등장 빈도수가 threshold보다 작으면
    if(value < threshold):
        rare_cnt = rare_cnt + 1
        rare_freq = rare_freq + value

print('단어 집합(vocabulary)의 크기 :',total_cnt)
print('등장 빈도가 %s번 이하인 희귀 단어의 수: %s'%(threshold - 1, rare_cnt))
print("단어 집합에서 희귀 단어의 비율:", (rare_cnt / total_cnt)*100)
print("전체 등장 빈도에서 희귀 단어 등장 빈도 비율:", (rare_freq / total_freq)*100)
# Out:
# 단어 집합(vocabulary)의 크기 : 43744
# 등장 빈도가 2번 이하인 희귀 단어의 수: 24328
# 단어 집합에서 희귀 단어의 비율: 55.61448427212875
# 전체 등장 빈도에서 희귀 단어 등장 빈도 비율: 1.9124308966832326

# %%
# 전체 단어 개수 중 빈도수 2이하인 단어는 제거.
# 0번 패딩 토큰을 고려하여 + 1
vocab_size = total_cnt - rare_cnt + 1
print('단어 집합의 크기 :',vocab_size)
# Out:
# 단어 집합의 크기 : 19417

# %%
# 케라스 토크나이저의 인자로 넘긴 후 텍스트 시퀀스를 정수 시퀀스로 변환 (0 ~ 19416)
tokenizer = Tokenizer(vocab_size) 
tokenizer.fit_on_texts(X_train)
X_train = tokenizer.texts_to_sequences(X_train)
X_test = tokenizer.texts_to_sequences(X_test)

# %%
type(X_train)
# Out:
# list

# %%
# 변환 됐는지 확인
print(X_train[:4])
# Out:
# [[451, 15, 255, 652], [911, 453, 39, 592, 1, 209, 1447, 23, 957, 668, 18], [381, 2444, 2311, 5668, 2, 216, 8], [6492, 100, 8125, 214, 53, 3, 24, 3609]]

# %%
y_train = np.array(train_data['label'])
y_test = np.array(test_data['label'])

# %%
#빈 샘플 제거
drop_train = [index for index, sentence in enumerate(X_train) if len(sentence) < 1]

X_train = np.delete(X_train, drop_train, axis=0)
y_train = np.delete(y_train, drop_train, axis=0)
print(len(X_train))
print(len(y_train))
# Out:
# 148474
# 148474

# %%
# 서로다른 길이의 리뷰들의 길이를 동일하게 맞춰주는 패딩 작업 진행
print('리뷰의 최대 길이 :',max(len(review) for review in X_train))
print('리뷰의 평균 길이 :',sum(map(len, X_train))/len(X_train))
plt.hist([len(review) for review in X_train], bins=50)
plt.xlabel('length of samples')
plt.ylabel('number of samples')
plt.show()
# Out:
# 리뷰의 최대 길이 : 68
# 리뷰의 평균 길이 : 10.338106335115912

# %%
def below_threshold_len(max_len, nested_list):
    count = 0
    for sentence in nested_list:
        if(len(sentence) <= max_len):
            count = count + 1
    print('전체 샘플 중 길이가 %s 이하인 샘플의 비율: %s'%(max_len, (count / len(nested_list))*100))

# %%
max_len = 50
below_threshold_len(max_len, X_train)
# Out:
# 전체 샘플 중 길이가 50 이하인 샘플의 비율: 99.96026240284495

# %%
X_train = pad_sequences(X_train, maxlen=max_len)
X_test = pad_sequences(X_test, maxlen=max_len)

# %%
# 다 대 일 구조의 LSTM 모델 사용, 이진 분류 문제 수행
from tensorflow.keras.layers import Embedding, Dense, LSTM
from tensorflow.keras.models import Sequential
from tensorflow.keras.models import load_model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

embedding_dim = 100
hidden_units = 128

model = Sequential()
model.add(Embedding(vocab_size, embedding_dim))
model.add(LSTM(hidden_units))
model.add(Dense(1, activation='sigmoid'))

es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=50)
mc = ModelCheckpoint('best_model.h5', monitor='val_acc', mode='max', verbose=1, save_best_only=True)

model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['acc'])
history = model.fit(X_train, y_train, epochs=100, callbacks=[es, mc], batch_size=64, validation_split=0.2)
# Out:
# Epoch 1/100
# 1853/1856 [============================>.] - ETA: 0s - loss: 0.3878 - acc: 0.8240
# Epoch 00001: val_acc improved from -inf to 0.84832, saving model to best_model.h5
# 1856/1856 [==============================] - 27s 15ms/step - loss: 0.3877 - acc: 0.8240 - val_loss: 0.3490 - val_acc: 0.8483
# Epoch 2/100
# 1855/1856 [============================>.] - ETA: 0s - loss: 0.3244 - acc: 0.8595
# Epoch 00002: val_acc improved from 0.84832 to 0.85722, saving model to best_model.h5
# 1856/1856 [==============================] - 26s 14ms/step - loss: 0.3244 - acc: 0.8595 - val_loss: 0.3318 - val_acc: 0.8572
# Epoch 3/100
# 1854/1856 [============================>.] - ETA: 0s - loss: 0.2993 - acc: 0.8733
# Epoch 00003: val_acc improved from 0.85722 to 0.86243, saving model to best_model.h5
# 1856/1856 [==============================] - 26s 14ms/step - loss: 0.2993 - acc: 0.8732 - val_loss: 0.3222 - val_acc: 0.8624
# Epoch 4/100
# 1853/1856 [============================>.] - ETA: 0s - loss: 0.2797 - acc: 0.8838
# Epoch 00004: val_acc improved from 0.86243 to 0.86281, saving model to best_model.h5
# 1856/1856 [==============================] - 26s 14ms/step - loss: 0.2797 - acc: 0.8839 - val_loss: 0.3225 - val_acc: 0.8628
# Epoch 5/100
# 1855/1856 [============================>.] - ETA: 0s - loss: 0.2642 - acc: 0.8916
# Epoch 00005: val_acc did not improve from 0.86281
# 1856/1856 [==============================] - 26s 14ms/step - loss: 0.2642 - acc: 0.8916 - val_loss: 0.3218 - val_acc: 0.8617
# Epoch 6/100
# 1855/1856 [============================>.] - ETA: 0s - loss: 0.2492 - acc: 0.8992
# Epoch 00006: val_acc did not improve from 0.86281
# 1856/1856 [==============================] - 26s 14ms/step - loss: 0.2492 - acc: 0.8993 - val_loss: 0.3278 - val_acc: 0.8596
# Epoch 7/100
# 1855/1856 [============================>.] - ETA: 0s - loss: 0.2347 - acc: 0.9059
# Epoch 00007: val_acc did not improve from 0.86281
# 1856/1856 [==============================] - 26s 14ms/step - loss: 0.2346 - acc: 0.9059 - val_loss: 0.3327 - val_acc: 0.8582
# Epoch 8/100
# 1853/1856 [============================>.] - ETA: 0s - loss: 0.2201 - acc: 0.9128
# Epoch 00008: val_acc did not improve from 0.86281
# 1856/1856 [==============================] - 26s 14ms/step - loss: 0.2201 - acc: 0.9128 - val_loss: 0.3490 - val_acc: 0.8588
# Epoch 9/100
# 1855/1856 [============================>.] - ETA: 0s - loss: 0.2047 - acc: 0.9205
# Epoch 00009: val_acc did not improve from 0.86281
# 1856/1856 [==============================] - 26s 14ms/step - loss: 0.2047 - acc: 0.9205 - val_loss: 0.3552 - val_acc: 0.8552
# Epoch 10/100
# 1856/1856 [==============================] - ETA: 0s - loss: 0.1903 - acc: 0.9264
# Epoch 00010: val_acc did not improve from 0.86281
# 1856/1856 [==============================] - 26s 14ms/step - loss: 0.1903 - acc: 0.9264 - val_loss: 0.3734 - val_acc: 0.8510
# Epoch 11/100
# 1854/1856 [============================>.] - ETA: 0s - loss: 0.1752 - acc: 0.9327
# Epoch 00011: val_acc did not improve from 0.86281
# 1856/1856 [==============================] - 26s 14ms/step - loss: 0.1752 - acc: 0.9327 - val_loss: 0.3846 - val_acc: 0.8497
# Epoch 12/100
# 1855/1856 [============================>.] - ETA: 0s - loss: 0.1603 - acc: 0.9395
# Epoch 00012: val_acc did not improve from 0.86281
# 1856/1856 [==============================] - 26s 14ms/step - loss: 0.1603 - acc: 0.9395 - val_loss: 0.4051 - val_acc: 0.8472
# Epoch 13/100
# 1853/1856 [============================>.] - ETA: 0s - loss: 0.1461 - acc: 0.9449
# Epoch 00013: val_acc did not improve from 0.86281
# 1856/1856 [==============================] - 26s 14ms/step - loss: 0.1461 - acc: 0.9449 - val_loss: 0.4270 - val_acc: 0.8440
# Epoch 14/100
# 1856/1856 [==============================] - ETA: 0s - loss: 0.1314 - acc: 0.9511
# Epoch 00014: val_acc did not improve from 0.86281
# 1856/1856 [==============================] - 26s 14ms/step - loss: 0.1314 - acc: 0.9511 - val_loss: 0.4690 - val_acc: 0.8415
# Epoch 15/100
# 1854/1856 [============================>.] - ETA: 0s - loss: 0.1168 - acc: 0.9566
# Epoch 00015: val_acc did not improve from 0.86281
# 1856/1856 [==============================] - 26s 14ms/step - loss: 0.1168 - acc: 0.9565 - val_loss: 0.5159 - val_acc: 0.8310
# Epoch 16/100
# 1855/1856 [============================>.] - ETA: 0s - loss: 0.1035 - acc: 0.9620
# Epoch 00016: val_acc did not improve from 0.86281
# 1856/1856 [==============================] - 26s 14ms/step - loss: 0.1035 - acc: 0.9620 - val_loss: 0.5432 - val_acc: 0.8256
# Epoch 17/100
# 1853/1856 [============================>.] - ETA: 0s - loss: 0.0915 - acc: 0.9671
# Epoch 00017: val_acc did not improve from 0.86281
# 1856/1856 [==============================] - 26s 14ms/step - loss: 0.0915 - acc: 0.9671 - val_loss: 0.5804 - val_acc: 0.8308
# Epoch 18/100
# 1853/1856 [============================>.] - ETA: 0s - loss: 0.0807 - acc: 0.9713
# Epoch 00018: val_acc did not improve from 0.86281
# 1856/1856 [==============================] - 26s 14ms/step - loss: 0.0807 - acc: 0.9713 - val_loss: 0.6236 - val_acc: 0.8299
# Epoch 19/100
# 1854/1856 [============================>.] - ETA: 0s - loss: 0.0719 - acc: 0.9745
# Epoch 00019: val_acc did not improve from 0.86281
# 1856/1856 [==============================] - 26s 14ms/step - loss: 0.0718 - acc: 0.9746 - val_loss: 0.6830 - val_acc: 0.8242
# Epoch 20/100
# 1854/1856 [============================>.] - ETA: 0s - loss: 0.0636 - acc: 0.9778
# Epoch 00020: val_acc did not improve from 0.86281
# 1856/1856 [==============================] - 26s 14ms/step - loss: 0.0636 - acc: 0.9778 - val_loss: 0.7220 - val_acc: 0.8298
# Epoch 21/100
# 1855/1856 [============================>.] - ETA: 0s - loss: 0.0564 - acc: 0.9804
# Epoch 00021: val_acc did not improve from 0.86281
# 1856/1856 [==============================] - 26s 14ms/step - loss: 0.0564 - acc: 0.9804 - val_loss: 0.7677 - val_acc: 0.8225
# Epoch 22/100
# 1855/1856 [============================>.] - ETA: 0s - loss: 0.0504 - acc: 0.9828
# Epoch 00022: val_acc did not improve from 0.86281
# 1856/1856 [==============================] - 26s 14ms/step - loss: 0.0505 - acc: 0.9828 - val_loss: 0.8277 - val_acc: 0.8184
# Epoch 23/100
# 1855/1856 [============================>.] - ETA: 0s - loss: 0.0462 - acc: 0.9847
# Epoch 00023: val_acc did not improve from 0.86281
# 1856/1856 [==============================] - 26s 14ms/step - loss: 0.0462 - acc: 0.9847 - val_loss: 0.8285 - val_acc: 0.8223
# Epoch 24/100
# 1855/1856 [============================>.] - ETA: 0s - loss: 0.0408 - acc: 0.9863
# Epoch 00024: val_acc did not improve from 0.86281
# 1856/1856 [==============================] - 26s 14ms/step - loss: 0.0408 - acc: 0.9863 - val_loss: 0.8790 - val_acc: 0.8205
# Epoch 25/100
# 1855/1856 [============================>.] - ETA: 0s - loss: 0.0370 - acc: 0.9879
# Epoch 00025: val_acc did not improve from 0.86281
# 1856/1856 [==============================] - 26s 14ms/step - loss: 0.0370 - acc: 0.9879 - val_loss: 0.9330 - val_acc: 0.8152
# Epoch 26/100
# 1854/1856 [============================>.] - ETA: 0s - loss: 0.0345 - acc: 0.9889
# Epoch 00026: val_acc did not improve from 0.86281
# 1856/1856 [==============================] - 26s 14ms/step - loss: 0.0344 - acc: 0.9889 - val_loss: 0.9763 - val_acc: 0.8166
# Epoch 27/100
# 1853/1856 [============================>.] - ETA: 0s - loss: 0.0321 - acc: 0.9897
# Epoch 00027: val_acc did not improve from 0.86281
# 1856/1856 [==============================] - 26s 14ms/step - loss: 0.0321 - acc: 0.9897 - val_loss: 0.9929 - val_acc: 0.8127
# Epoch 28/100
# 1856/1856 [==============================] - ETA: 0s - loss: 0.0299 - acc: 0.9904
# Epoch 00028: val_acc did not improve from 0.86281
# 1856/1856 [==============================] - 26s 14ms/step - loss: 0.0299 - acc: 0.9904 - val_loss: 1.0181 - val_acc: 0.8167
# Epoch 29/100
# 1856/1856 [==============================] - ETA: 0s - loss: 0.0281 - acc: 0.9911
# Epoch 00029: val_acc did not improve from 0.86281
# 1856/1856 [==============================] - 26s 14ms/step - loss: 0.0281 - acc: 0.9911 - val_loss: 1.0547 - val_acc: 0.8096
# Epoch 30/100
# 1855/1856 [============================>.] - ETA: 0s - loss: 0.0267 - acc: 0.9915
# Epoch 00030: val_acc did not improve from 0.86281
# 1856/1856 [==============================] - 26s 14ms/step - loss: 0.0267 - acc: 0.9915 - val_loss: 1.0470 - val_acc: 0.8143
# Epoch 31/100
# 1855/1856 [============================>.] - ETA: 0s - loss: 0.0248 - acc: 0.9922
# Epoch 00031: val_acc did not improve from 0.86281
# 1856/1856 [==============================] - 26s 14ms/step - loss: 0.0248 - acc: 0.9922 - val_loss: 1.1073 - val_acc: 0.8154
# Epoch 32/100
# 1856/1856 [==============================] - ETA: 0s - loss: 0.0244 - acc: 0.9922
# Epoch 00032: val_acc did not improve from 0.86281
# 1856/1856 [==============================] - 26s 14ms/step - loss: 0.0244 - acc: 0.9922 - val_loss: 1.0856 - val_acc: 0.8124
# Epoch 33/100
# 1854/1856 [============================>.] - ETA: 0s - loss: 0.0234 - acc: 0.9927
# Epoch 00033: val_acc did not improve from 0.86281
# 1856/1856 [==============================] - 26s 14ms/step - loss: 0.0234 - acc: 0.9927 - val_loss: 1.1321 - val_acc: 0.8066
# Epoch 34/100
# 1855/1856 [============================>.] - ETA: 0s - loss: 0.0228 - acc: 0.9926
# Epoch 00034: val_acc did not improve from 0.86281
# 1856/1856 [==============================] - 26s 14ms/step - loss: 0.0228 - acc: 0.9926 - val_loss: 1.1012 - val_acc: 0.8131
# Epoch 35/100
# 1856/1856 [==============================] - ETA: 0s - loss: 0.0221 - acc: 0.9929
# Epoch 00035: val_acc did not improve from 0.86281
# 1856/1856 [==============================] - 26s 14ms/step - loss: 0.0221 - acc: 0.9929 - val_loss: 1.1475 - val_acc: 0.8117
# Epoch 36/100
# 1853/1856 [============================>.] - ETA: 0s - loss: 0.0207 - acc: 0.9932
# Epoch 00036: val_acc did not improve from 0.86281
# 1856/1856 [==============================] - 26s 14ms/step - loss: 0.0207 - acc: 0.9932 - val_loss: 1.1720 - val_acc: 0.8124
# Epoch 37/100
# 1856/1856 [==============================] - ETA: 0s - loss: 0.0208 - acc: 0.9934
# Epoch 00037: val_acc did not improve from 0.86281
# 1856/1856 [==============================] - 26s 14ms/step - loss: 0.0208 - acc: 0.9934 - val_loss: 1.1625 - val_acc: 0.8114
# Epoch 38/100
# 1856/1856 [==============================] - ETA: 0s - loss: 0.0204 - acc: 0.9936
# Epoch 00038: val_acc did not improve from 0.86281
# 1856/1856 [==============================] - 26s 14ms/step - loss: 0.0204 - acc: 0.9936 - val_loss: 1.1984 - val_acc: 0.8102
# Epoch 39/100
# 1854/1856 [============================>.] - ETA: 0s - loss: 0.0201 - acc: 0.9937
# Epoch 00039: val_acc did not improve from 0.86281
# 1856/1856 [==============================] - 26s 14ms/step - loss: 0.0201 - acc: 0.9937 - val_loss: 1.1962 - val_acc: 0.8110
# Epoch 40/100
# 1853/1856 [============================>.] - ETA: 0s - loss: 0.0196 - acc: 0.9937
# Epoch 00040: val_acc did not improve from 0.86281
# 1856/1856 [==============================] - 26s 14ms/step - loss: 0.0196 - acc: 0.9937 - val_loss: 1.1709 - val_acc: 0.8192
# Epoch 41/100
# 1853/1856 [============================>.] - ETA: 0s - loss: 0.0188 - acc: 0.9940
# Epoch 00041: val_acc did not improve from 0.86281
# 1856/1856 [==============================] - 26s 14ms/step - loss: 0.0188 - acc: 0.9940 - val_loss: 1.1768 - val_acc: 0.8104
# Epoch 42/100
# 1853/1856 [============================>.] - ETA: 0s - loss: 0.0191 - acc: 0.9938
# Epoch 00042: val_acc did not improve from 0.86281
# 1856/1856 [==============================] - 26s 14ms/step - loss: 0.0191 - acc: 0.9938 - val_loss: 1.2040 - val_acc: 0.8169
# Epoch 43/100
# 1853/1856 [============================>.] - ETA: 0s - loss: 0.0190 - acc: 0.9939
# Epoch 00043: val_acc did not improve from 0.86281
# 1856/1856 [==============================] - 26s 14ms/step - loss: 0.0190 - acc: 0.9939 - val_loss: 1.2093 - val_acc: 0.8115
# Epoch 44/100
# 1854/1856 [============================>.] - ETA: 0s - loss: 0.0184 - acc: 0.9941
# Epoch 00044: val_acc did not improve from 0.86281
# 1856/1856 [==============================] - 26s 14ms/step - loss: 0.0184 - acc: 0.9941 - val_loss: 1.2254 - val_acc: 0.8071
# Epoch 45/100
# 1855/1856 [============================>.] - ETA: 0s - loss: 0.0179 - acc: 0.9942
# Epoch 00045: val_acc did not improve from 0.86281
# 1856/1856 [==============================] - 26s 14ms/step - loss: 0.0179 - acc: 0.9942 - val_loss: 1.2595 - val_acc: 0.8073
# Epoch 46/100
# 1853/1856 [============================>.] - ETA: 0s - loss: 0.0179 - acc: 0.9943
# Epoch 00046: val_acc did not improve from 0.86281
# 1856/1856 [==============================] - 26s 14ms/step - loss: 0.0179 - acc: 0.9943 - val_loss: 1.2738 - val_acc: 0.8149
# Epoch 47/100
# 1853/1856 [============================>.] - ETA: 0s - loss: 0.0183 - acc: 0.9941
# Epoch 00047: val_acc did not improve from 0.86281
# 1856/1856 [==============================] - 26s 14ms/step - loss: 0.0183 - acc: 0.9941 - val_loss: 1.2232 - val_acc: 0.8096
# Epoch 48/100
# 1855/1856 [============================>.] - ETA: 0s - loss: 0.0176 - acc: 0.9943
# Epoch 00048: val_acc did not improve from 0.86281
# 1856/1856 [==============================] - 26s 14ms/step - loss: 0.0176 - acc: 0.9943 - val_loss: 1.2594 - val_acc: 0.8081
# Epoch 49/100
# 1854/1856 [============================>.] - ETA: 0s - loss: 0.0181 - acc: 0.9941
# Epoch 00049: val_acc did not improve from 0.86281
# 1856/1856 [==============================] - 26s 14ms/step - loss: 0.0181 - acc: 0.9941 - val_loss: 1.2416 - val_acc: 0.8068
# Epoch 50/100
# 1856/1856 [==============================] - ETA: 0s - loss: 0.0178 - acc: 0.9943
# Epoch 00050: val_acc did not improve from 0.86281
# 1856/1856 [==============================] - 26s 14ms/step - loss: 0.0178 - acc: 0.9943 - val_loss: 1.2365 - val_acc: 0.8064
# Epoch 51/100
# 1855/1856 [============================>.] - ETA: 0s - loss: 0.0177 - acc: 0.9942
# Epoch 00051: val_acc did not improve from 0.86281
# 1856/1856 [==============================] - 26s 14ms/step - loss: 0.0177 - acc: 0.9942 - val_loss: 1.2502 - val_acc: 0.8142
# Epoch 52/100
# 1855/1856 [============================>.] - ETA: 0s - loss: 0.0175 - acc: 0.9942
# Epoch 00052: val_acc did not improve from 0.86281
# 1856/1856 [==============================] - 26s 14ms/step - loss: 0.0175 - acc: 0.9942 - val_loss: 1.2415 - val_acc: 0.8048
# Epoch 53/100
# 1853/1856 [============================>.] - ETA: 0s - loss: 0.0177 - acc: 0.9944
# Epoch 00053: val_acc did not improve from 0.86281
# 1856/1856 [==============================] - 26s 14ms/step - loss: 0.0177 - acc: 0.9944 - val_loss: 1.2324 - val_acc: 0.8091
# Epoch 54/100
# 1854/1856 [============================>.] - ETA: 0s - loss: 0.0175 - acc: 0.9945
# Epoch 00054: val_acc did not improve from 0.86281
# 1856/1856 [==============================] - 26s 14ms/step - loss: 0.0175 - acc: 0.9944 - val_loss: 1.2971 - val_acc: 0.8078
# Epoch 55/100
# 1852/1856 [============================>.] - ETA: 0s - loss: 0.0178 - acc: 0.9942
# Epoch 00055: val_acc did not improve from 0.86281
# 1856/1856 [==============================] - 26s 14ms/step - loss: 0.0178 - acc: 0.9942 - val_loss: 1.2189 - val_acc: 0.8138
# Epoch 00055: early stopping

# %%
loaded_model = load_model('best_model.h5')
print("\n 테스트 정확도: %.4f" % (loaded_model.evaluate(X_test, y_test)[1]))
# Out:
# 1550/1550 [==============================] - 6s 4ms/step - loss: 0.3312 - acc: 0.8576
#
#  테스트 정확도: 0.8576

# %%
def sentiment_predict(new_sentence):
    new_sentence = re.sub(r'[^ㄱ-ㅎㅏ-ㅣ가-힣 ]','', new_sentence)
    new_sentence = okt.morphs(new_sentence, stem=True) # 토큰화
    new_sentence = [word for word in new_sentence if not word in stopwords] # 불용어 제거
    encoded = tokenizer.texts_to_sequences([new_sentence]) # 정수 인코딩
    pad_new = pad_sequences(encoded, maxlen = max_len) # 패딩
    score = float(loaded_model.predict(pad_new)) # 예측
    if(score > 0.5):
        print("{:.2f}% 확률로 긍정 리뷰입니다.\n".format(score * 100))
    else:
        print("{:.2f}% 확률로 부정 리뷰입니다.\n".format((1 - score) * 100))

# %%
sentiment_predict(input('감성 분석할 문장을 입력하시오: '))
# Out:
# 감성 분석할 문장을 입력하시오: 과연 내 인생영화
# 92.39% 확률로 긍정 리뷰입니다.
